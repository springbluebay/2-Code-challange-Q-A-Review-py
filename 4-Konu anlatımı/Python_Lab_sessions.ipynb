# %%
# LAB 20/04
condition = True

if condition :
    x = 1
else:
    x = 0
    
print(x)

x = 1 if condition else 0 # codun body si başa gelir aynı sonucu verir. prog hızlandırmak için.
print(x)

# %%
my_list = []

for i in range(5):
    my_list.append(i**2)

print(my_list) #print alt satırda yana dayalı olması etki ediyor çıktıya

# %%
my_list2= [i**2 for i in range(5)]

print([i**2 for i in range(5)]) #for un içindeki ana body başa gelir.
print(my_list2)

# %%
no1 = 10_000_000
no2 = 100_000_000

adding = no1 + no2
print(adding)         #### python "_" yokmuş gibi davranıyor
print(f'{adding:,}')  #### "_" ların yerine "," eklnir

# %%
items = (10, 20) #tuple
print (items)

# %%
a, _, b, _ = (10, 20, 30, 40) ## listenin içindeki değerlerin kaybolmasını istemiyoruz. _ ile değerleri göstermiyoruz.

print(a)
print(b)

# %%
print(*"clarusway")

# %%
x, y, *z = (11, 22, 33, 44, 55) # z'nin başına * koyarsak kalan son 3 değeri atar.

print(x)
print(y)
print(z)
print(type(z))    # python liste içinde kalan diğer değerleri yeni bir lsite yapıp oraya atıyor

# %%
x, y, *z, t = (11, 22, 33, 44, 55, 66, 77) # x 11'e y 22'e atanır. z ise son değer hariç diğerleri atanır. "recorunce" denir

print(x)
print(y)
print(z)
print(t)

x, y, *_, t = (11, 22, 33, 44, 55, 66, 77) # * ve _ ortak kullanımı
print("--------------")
print(x)
print(y)
print(t)
print("--------------")
print(_) ### "_" ile de "_" 'a attığımız değeri tekrar çağırabiliriz.

# %%
birds_Tr = ["bulbul", "anka", "serce", "kartal"]

index = 0

for bird in birds_Tr:
    print(index, bird)
    index +=1

# %%
for index, bird in enumerate(birds_Tr, start=1): #nuralandırıyoruz
    print(index, bird)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-257ea593ef39> in <module>
# ----> 1 for index, bird in enumerate(birds_Tr, start=1): #nuralandırıyoruz
#       2     print(index, bird)
#
# NameError: name 'birds_Tr' is not defined

# %%
countries = ["Turkey", "Iraq", "Pakistan", "ABD"]
capitals = ["Ankara", "Bagdat", "Islamabad", "Washıngton"]

for index, country in enumerate(countries):
    capital =capitals[index]
    print(f"Capital of {country} is : {capital}")

print("--------------")

countries = ["Turkey", "Iraq", "Pakistan", "ABD"]
capitals = ["Ankara", "Bagdat", "Islamabad", "Washıngton"]

for country, capitals in zip(countries, capitals):         #aynısını zip ile yaptık. 3 tanede olur
    print(f"Capital of {country} is : {capital}")

print("--------------")

countries = ["Turkey", "Iraq", "Pakistan", "ABD"]
capitals = ["Ankara", "Bagdat", "Islamabad", "Washıngton"]

for values in zip(countries, capitals):            #her birinden bir değer alıp tuple oluşturuyor.
    print(values)
# Out:
# Capital of Turkey is : Ankara
# Capital of Iraq is : Bagdat
# Capital of Pakistan is : Islamabad
# Capital of ABD is : Washıngton
# --------------
# Capital of Turkey is : Washıngton
# Capital of Iraq is : Washıngton
# Capital of Pakistan is : Washıngton
# Capital of ABD is : Washıngton
# --------------
# ('Turkey', 'Ankara')
# ('Iraq', 'Bagdat')
# ('Pakistan', 'Islamabad')
# ('ABD', 'Washıngton')

# %%
#25.04 ders

odds = []
evens = []
for i in range(20):
    if i %2 == 0 :
        evens.append(i)
    else:
        odds.append(i)

print(f'in that {range(20)} my odd numbers are "{odds}" an my even numbers are "{evens}"')

# %%
for i in range(2,10,2):
     print(i, "\n")

# %%
number = int(input("input a number :"))
if number > 10:
    print("The number is equal or greater than 10")
elif number <10:
    print("The number is less than 10")
else:
    print("False")

# %%
#You can write a "single line" code to check two strings, whether they are anagram or not. If they are anagram it should give True, False otherwise.

str1= input("please enter a word")
str2= input("please enter a word")
print("the values are anagram") if sorted(str2)==sorted(str1) else print("the values are not anagram")

# %%
str1= set(input("please enter a word"))
str2= set(input("please enter a word"))
print("True") if str1.difference(str2)==set() else print("False")  #set ile yaklaşılması yanlış tekrarlayan harfleri yazmıyor..

# %%
x = min("Mike", "John", "Vicky")


print(x)

# %%
num = [1, 2, 0, 1, 4, 5, 7, 2, 8, 2, 2]

item = max(num, key = num.count)
repetition = num.count(item)
print("bu listede en çok tekrarlayan sayı {}, bu sayı toplamda {} defa tekrarlamış".format(item, repetition))

# %%
## Write a function that returns the least common multiple (LCM) of two integers.//Both values will be positive.//The LCM is the smallest integer that divides both numbers such that the remainder is zero.

n1= int(input("enter positive number:"))
n2= int(input("enter another positive number:"))

small=[2,3,5,7]

for i in small:
    while n1%i==0 and n2%i==0 :
        top=
        for i in small:
            if n2%i==0:
    #  and n2%i==0 :
    #     print("true")
    #     break

# %%
# 05.05.2020 lab joseph/-/

kelime = input("sesli harfle başlayıp sesli harfle biten bir kelime girin")

print(kelime.startwith(("a","e","o","u","i")) and kelime.endwith(("a","e","o","u","i")))

# %%
my_list=[1, 2, 30, 40, 50, 60, 70, 80, 90]

lst_kare=[x**2 for x in my_list]
lst_kare

print(next(genere)) #her çalıştırdığınızda bir sonraki element değerini yazdırıyoruz..

# %%
#yukarıdaki aynı şeyi tuple ile yapıtoruz.
my_list=[1, 2, 30, 40, 50, 60, 70, 80, 90]
genere = (x**2 for x in my_list)
genere

# %%
print(next(genere))
print(type(genere))

# %%
import sys
print(sys.getsizeof(lst_kare))
print(sys.getsizeof(genere)) # tuple olan daha az yer kaplıyor

# %%
# generator benzeri zip fonksiyonu var.

list1 = ["ahmet","mehmet","cemal"]
list2 = [22, 33, 44]

gene = zip(list1, list2) 
gene

print(next(gene)) # next ile teker teker iterate ediyoruz

# %%
gene_enum = enumerate(list1) # herhangi bir iterable collectionda sıra numarı veriyor. ve tuple da topluyor
gene_enum  #tuple da toplar.

# %%
print(next(gene_enum))  #bizde iterate ederek alırız.

# %%
# ahmet
weekday = True
vacation = True
if weekday == False or vacation == True:
    print('Sleep-in!')
else:
    print('Go to work!')
